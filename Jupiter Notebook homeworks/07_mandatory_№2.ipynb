# %% [markdown]
# #### Вопрос 1
# ## Калорийность продукта
# Вася пришел в магазин и хочет узнать, сколько килокалорий в выбранном продукте, но на упаковке написана только ценность продукта в джоулях. Помогите Васе узнать калорийность продукта, если одна килокалория равна 4184 джоулям.
#
# #### ТРЕБУЕМАЯ ФУНКЦИЯ
#
# Функция get_calories, которая принимает в качестве параметра целое число joule — ценность продукта в джоулях.
# Функция должна вернуть ценность продукта в килокалориях.
# В этой задаче вы только определяете функцию: не нужно считывать ввод и вызывать ее, мы сделаем это автоматически при проверке.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# def, return, арифметические операции
# ЧТО ДЕЛАЕМ:
# Задаем функцию get_calories() с одним параметром — joule
# Возвращаем (return) количество джоулей (joule) разделенное на 4184
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | 4184 | 1.0 |

# %%
def get_calories(joule):
    return joule / 4184

# %% [markdown]
# #### Вопрос 2
# ## Экономная редакция
# Катя работает редактором в журнале. Журнал не очень прибыльный и приходится экономить на чернилах, поэтому вместо букв Ё/ё в текстах используются Е/е. В штат недавно наняли нового журналиста, который написал статью, в которой очень много букв Ё/ё. Помогите Кате исправить ситуацию.
#
# #### ТРЕБУЕМАЯ ФУНКЦИЯ
#
# Функция replacer, которая принимает в качестве параметра список строк strings и редактирует этот список, заменяя во всех строках Ё/ё на Е/е.
# Функция ничего не возвращает.
# В этой задаче вы только определяете функцию: не нужно считывать ввод и вызывать ее, мы сделаем это автоматически при проверке.
#
# Примечание: если по какой-то мистической причине ваша задача не проходит тесты, но вы уверены в правильности решения — скопируйте в ваше решение буквы Ë/ё из текста задачи (в вашей раскладке эта буква может быть на самом деле латинской, а решение из-за этого не проходить тесты).
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# def, for, range, len, replace
#
# ЧТО ДЕЛАЕМ:
# Определите функцию replacer, которая принимает один параметр — strings.
# Внутри функции запустите цикл for i in range(), который переберет все элементы списка (используйте функцию len). Обращаясь к строкам внутри списка по индексу для каждой строки:
# Замените буквы Ë на Е и ё на е (это можно сделать, использовав два метода .replace() подряд).
# Сохраните измененную строку в в список strings под тем же индексом.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | ['Ёж', 'зелёный', 'ЕЁ', 'гЁТЬёсЮёёзЪЁЁЙ'] | ['Еж', 'зеленый', 'ЕЕ', 'гЕТЬесЮеезЪЕЕЙ'] |

# %%
def replacer(strings):
    for i in range(len(strings)):
        strings[i] = strings[i].replace('Ё', 'Е').replace('ё', 'е')

# %% [markdown]
# #### Вопрос 3
# ## Подписки в Инстаграме
# Помогите блогеру Сене выбрать из подписок в инстаграме аккаунты с определенными размерами аудитории, чтобы отправить предложение о сотрудничестве.
#
# #### ТРЕБУЕМАЯ ФУНКЦИЯ
#
# Функция filter_accounts, которая принимает в качестве параметра словарь accounts, ключами которого являются адреса аккаунтов, а значениями — число подписчиков.
# Также функция принимает в качестве параметров целые числа min_followers и max_followers, где min_followers меньше либо равен max_followers.
# Функция должна возвращать список адресов аккаунтов, где число подписчиков находится в промежутке между min_followers и max_followers включительно, адреса должны быть отсортированы в лексикографическом порядке.
# В этой задаче вы только определяете функцию: не нужно считывать ввод и вызывать ее, мы сделаем это автоматически при проверке.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# def, for, append, return, sorted
#
# ЧТО ДЕЛАЕМ:
# Создаем функцию filter_accounts, которая принимает три параметра — словарь accounts и два числа (min_followers и max_followers).
# Внутри функции создаем пустой список.
# Внутри функции запускаем цикл по словарю accounts. Для каждого ключа в аccounts делаем проверку: если количество подписчиков (значение ключа) находится в промежутке между минимальным количеством и максимальным (min_followers и max_followers), то добавляем аккаунт в список из п. 2.
# Возвращаем отсортированный по алфавиту список из п. 2.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | {'@blogger13999': 2308, '@dragondragon': 1473, '@account': 1400, '@flowers': 1250, '@banana': 1500}, 1400, 1500 | ['@account', '@banana', '@dragondragon'] |

# %%
def filter_accounts(accounts, min_followers, max_followers):
    return sorted([k for k, v in accounts.items() if min_followers <= v <=  max_followers])

# %% [markdown]
# #### Вопрос 4
# ## Поиск слова
# Вводится текст в две строки и число N. Определить, есть ли в тексте N-ое слово (нумеруя с 1) и вывести его. Если слова нет, вывести "Такого слова нет".
#
# #### ФОРМАТ ВВОДА
# Две непустые строки и целое положительное число N.
#
# #### ФОРМАТ ВЫВОДА
# Строка
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), int(), split(), сложение списков, len(), print(), проверка условий
#
# ЧТО ДЕЛАЕМ:
# Считать с клавиатуры в новую переменную первую строку с текстом, сразу разделить на список слов (input().split()).
# Считать с клавиатуры в новую переменную вторую строку с текстом, сразу разделить на список слов.
# Считать с клавиатуры в новую переменную целое число N.
# Склеить списки из п. 1 и п. 2 с помощью сложения и записать в новую переменную.
# Проверить условие:
# если переменная из п. 3 меньше либо равна (<=) длине списка из п. 4, то напечатать слово из этого списка с индексом N - 1,
# в ином случае(else) напечатать текст "Такого слова нет".
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | В траве сидел кузнечик | Зелененький
# | Зелененький он был ||
# | 5 ||

# %%
s1 = input().split()
s2 = input().split()
N = int(input()) - 1
if N < len(s1 + s2):
    print((s1 + s2)[N])
else:
    print("Такого слова нет")
# Out:
# В траве сидел кузнечик
# Зелененький он был
# 5
# Зелененький

# %% [markdown]
# #### Вопрос 5
# ## Пароль
# Согласно политике безопасности банка, пароль не может содержать года рождения клиента — иначе вероятность подобрать пароль увеличивается. Напишите программу, которая будет проводить такую проверку.
#
# #### ФОРМАТ ВВОДА
# На первой строке — полный год рождения клиента (то есть 4 символа, например, «1968»).
# На второй строке — три варианта пароля, придуманных клиентом, записанных через пробел.
#
# #### ФОРМАТ ВЫВОДА
#
# True, если в пароле есть подстрока с годом рождения, и False, если нет.
# Ответ по каждому варианту пароля нужно выводить с новой строки.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), цикл for, проверка условий
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную год рождения (именно как строку, просто через input()).
# Считать строку с паролями в новую переменную, преобразовав ее в список (input().split()).
# Реализовать цикл for для списка из п. 2: Для каждого пароля проверить: если год содержится в пароле, то печатать True. В ином случае печатать False.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | 1990 | True |
# | kotik1990seriy kotikseriy k1993seriy | False |
# | | False |

# %%
year = input()
pwd = input().split()
print(*map(lambda p: year in p, pwd), sep="\n")
# Out:
# 1990
# kotik1990seriy kotikseriy k1993seriy
# True
# False
# False

# %% [markdown]
# #### Вопрос 6
# ## Домашние дела - 1
# Женя и Саша распределяют между собой домашние дела из общего списка, при этом стараясь поделить работу пополам: если в списке четное количество дел, то Женя делает первую половину, а Саша — вторую; если в списке нечетное число задач, то задачу, которая оказалась посередине, они делают вместе (она попадает в список задач и Саши, и Жени).
#
# Напишите программу, которая принимает на вход общий список дел и выводит списки дел для Саши и Жени.
#
# #### ФОРМАТ ВВОДА
# Общий непустой список дел, перечисленных через запятую и пробел.
#
# #### ФОРМАТ ВЫВОДА
# Два списка через запятую и пробел: сначала список дел Жени, затем список дел Саши каждый список выводится с новой строки.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), range(), len(), print()
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную общий список дел (tasks). Сразу превращаем эту строку в список с помощью .split(). Обратите внимание, что разделитель здесь — запятая и пробел.
# Создать два пустых списка для списков дел Жени и Саши. Пустой список можно задать пустыми квадратными скобками ([]).
# Реализуем цикл for i in range(). В качестве границы интервала берем (len(tasks) // 2 + len(tasks) % 2) — таким образом для четного количества дел мы найдем половинку, а для нечетного количества дел (там где остаток от деления на 2 будет единицей) еще "зацепим" и дело, которое Саша и Женя разделят. Внутри цикла добавляем каждое дело под индексом i в список дел Саши.
# Реализуем второй цикл for i in range(). Здесь интервал от len(tasks) // 2 до len(tasks) и добавляем дела под индексом i в список дел Жени.
# Напечатать список Саши. Обратите внимание, что у вас должен выйти список дел в соответствующем оформлении. Это можно сделать как print(*Список Саши, sep=', ').
# Напечатать список Жени аналогично списку Саши.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | разморозить холодильник, вернуть книги в библиотеку, сварить сосиски, помыть пол, выгулять собаку | разморозить холодильник, вернуть книги в библиотеку, сварить сосиски |
# | | сварить сосиски, помыть пол, выгулять собаку |

# %%
todos = input().split(', ')
mid = len(todos) // 2 if len(todos) % 2 == 0 else len(todos) // 2 + 1
if len(todos) % 2:
    todo1 = todos[:mid]
    todo2 = todos[mid - 1:]
else:
    todo1 = todos[:mid]
    todo2 = todos[mid:]

print(', '.join(todo1), ', '.join(todo2), sep="\n")
# Out:
# разморозить холодильник, вернуть книги в библиотеку, сварить сосиски, помыть пол, выгулять собаку
# разморозить холодильник, вернуть книги в библиотеку, сварить сосиски
# сварить сосиски, помыть пол, выгулять собаку

# %% [markdown]
# #### Вопрос 7
# ## Спортсмены
# Через пробел в одну строку вводится список спортсменов в том порядке, в каком они заняли места на соревновании. Далее через пробел в одну строку вводятся места спортсменов. Определите по местам, какие спортсмены их заняли.
#
# #### ФОРМАТ ВВОДА
# Две строки. Первая строка с именами через пробел. Вторая строка с целыми положительными числами через пробел.
#
# #### ФОРМАТ ВЫВОДА
# Для каждого числа из ввода вывести строку формата "<место> занял <спортсмен>", либо строку формата "<место> никто не занял", если спортсмена на таком месте в введенном списке нет.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), range(), len(), цикл for , проверка условий с if, print()
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную строку с именами и сразу превратить ее в список с помощью split().
# Считать в новую переменную строку с местами и сразу превратить ее в список с помощью split(). Получим список цифр-строк.
# Теперь проходимся циклом for по списку мест — нам нужно вывести спортсменов, которые заняли эти места. Для каждого места делаем следующее:
# Чтобы превратить наши цифры-строки в индексы, которые понимает Python, нам нужно каждую превратить в целое число и вычесть единицу — сохраняем индекс в переменную.
# Проверяем, есть ли у нас в списке спортсмен под таким индексом — если индекс меньше длины списка имен спортсменов, то выводим имя, хранящееся под этим индексом. В других случаях пишем, что это место никто не занял.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | Чен Ханю Чжоу Уно Цзинь Коляда | 2 место занял Ханю |
# | 2 6 10 | 6 место занял Коляда |
# | | 10 место никто не занял |

# %%
names = input().split()
places = list(map(int, input().split()))
for i in places:
    if i - 1 < len(names):
        print(f"{i} место занял {names[i - 1]}")
    else:
        print(f"{i} место никто не занял")
# Out:
# Чен Ханю Чжоу Уно Цзинь Коляда
# 2 6 10
# 2 место занял Ханю
# 6 место занял Коляда
# 10 место никто не занял

# %% [markdown]
# #### Вопрос 8
# ## Волшебные палочки
#
# Менеджер магазина волшебных палочек Олливандера проверяет работоспособность магической системы учета проданных палочек. Выборочно он записывает информацию о проданных волшебных палочках в виде списка, содержащего имя и фамилию владельца, год приобретения и материал, из которого изготовлена палочка. Записи вводятся до тех пор, пока менеджер не введет слово "Конец". Иногда владелец магазина, Олливандер, хочет вспомнить всех, кто покупал у него палочку в определенный год. Если никто не купил палочку в указанный год, то выводится фраза: "В этот год никто не покупал волшебные палочки."
#
# #### ФОРМАТ ВВОДА
# Строки типа "ИФ владельца, год, материал". Строки вводятся до тех пора, пока не будет введена строка "Конец". Гарантируется, что будет введена как минимум одна строка с информацией о клиенте.
# Год.
#
# #### ФОРМАТ ВЫВОДА
# Строка типа "В <XXXX> году волшебную палочку купили:" и перечисление ИФ тех, кто купил волшебную палочку, а также уточнение материала, из которого она изготовлена (см. пример), строка заканчивается точкой. Либо строка "В этот год никто не покупал волшебные палочки."
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), цикл while, цикл for, split(), условный оператор, методы списков, .join(), print()
#
# ЧТО ДЕЛАЕМ:
# Создать пустой список, куда будем записывать информацию о клиентах.
# Считать в переменную строку с информацией о первом клиенте.
# Запустить цикл while: пока переменная из п. 2 не равна строке "Конец", добавить строку с информацией о клиенте в список из п. 1. Затем считать строку с информацией о новом клиенте.
# Считать в переменную строку с интересующим Олливандера годом.
# Создать новый пустой список, куда будем добавлять информацию только о клиентах, купивших палочки в этот год.
# Запускаем цикл for для списка из п. 1:
# для каждого клиента разбиваем строку с информацией по запятым и пробелам, сохраняем этот список в переменную.
# Проверяем условие: если второй элемент списка (первый для Python) равен интересующему нас году, то записываем в список из п. 5 f-строку вида "<ИМЯ КЛИНЕТА (первый элемент списка)> (материал - <МАТЕРИАЛ (третий элемент списка)>)". В итоге у нас получится список отформатированных строк или пустой список, если в этот год палочки никто не покупал.
# После завершения работы цикла проверяем условие — если длина списка из п. 5 равна нулю — печатаем, что палочки никто не покупал. В ином случае печатаем строку заданного формата. Например, можно вывести f-строку, а на место перечня клиентов вставить список из п. 5, объединенный через запятую с пробелом (', '.join()).
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | Долорес Амбридж, 1957, береза | В 1989 году волшебную палочку купили: Гермиона Грейнджер (материал - виноградная лоза), Невилл Долгопупс (материал - вишневое дерево).
# | Гермиона Грейнджер, 1989, виноградная лоза
# | Седрик Диггори, 1985, ясень
# | Невилл Долгопупс, 1989, вишневое дерево
# | Конец
# | 1989

# %%
dct = dict()
while True:
    s = input().split(', ')
    if s[0] == "Конец":
        break
    dct.setdefault(s[1], []).append(f"{s[0]} (материал - {s[2]})")
    
year = input()
if dct.get(year):
    print(f"В {year} году волшебную палочку купили: {', '.join(dct[year])}.")
else:
    print("В этот год никто не покупал волшебные палочки.")
# Out:
# Долорес Амбридж, 1957, береза
# Гермиона Грейнджер, 1989, виноградная лоза
# Седрик Диггори, 1985, ясень
# Невилл Долгопупс, 1989, вишневое дерево
# Конец
# 1989
# В 1989 году волшебную палочку купили: Гермиона Грейнджер (материал - виноградная лоза), Невилл Долгопупс (материал - вишневое дерево).

# %% [markdown]
# #### Вопрос 9
# ## Диета
# Петя решил придерживаться новой диеты — есть на ужин только продукты, названия которых имеют определенную длину и начинаются с определенной буквы. Помогите Пете определить, чем можно поужинать в рамках новой диеты. На вход подается список продуктов через запятую. На выходе программа выдает только те продукты, которые можно есть Пете, а если таких продуктов нет, то пишет "Нужно идти в магазин."
#
# #### ФОРМАТ ВВОДА
# Строка с названиями продуктов через запятую и пробел
# Буква, с которой должны начинаться названия продуктов
# Целое положительное число —  необходимая длина названия продукта
# Каждый ввод с новой строки.
#
# #### ФОРМАТ ВЫВОДА
# Строка типа "Сегодня Петя может съесть на ужин следующие продукты:" и перечисление продуктов через запятую (см. пример), либо строка "Нужно идти в магазин."
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), int(), split(), len(), append(), print(), join(), цикл for, проверка условия с if и else
#
# ЧТО ДЕЛАЕМ:
# Считайте в новую переменную строку. Разбейте ее, чтобы превратить в список. Обратите внимание, что разделитель — запятая и пробел.
# Считайте с клавиатуры в новую переменную букву.
# Считайте с клавиатуры в новую строку с числом, превратить его в тип integer.
# Создайте новый пустой список.
# Реализуйте цикл for. Для каждого элемента списка из п. 1 проверьте условие — строка начинается с заданной буквы и имеет определенную длину. Если продукт подходит по условию — добавьте его в список из п. 4.
# После завершения работы цикла, проверьте длину списка из п. 4 — если он пустой, то выводим строку про поход в магазин. Если нет — выводим слова из списка через запятую (с помощью * или join()).
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | бананы, яблоки, малина, молоко, батон, морковь | Сегодня Петя может съесть на ужин следующие продукты: малина, молоко. |
# | м |
# | 6 |

# %%
products = input().split(', ')
char, L = input(), int(input())
lst_diet = [p for p in products if p[0] == char and len(p) == L]
if lst_diet:
    print(f"Сегодня Петя может съесть на ужин следующие продукты: {', '.join(lst_diet)}.")
else:
    print("Нужно идти в магазин.")
# Out:
# бананы, яблоки, малина, молоко, батон, морковь
# м
# 6
# Сегодня Петя может съесть на ужин следующие продукты: малина, молоко.

# %% [markdown]
# #### Вопрос 10
# ## Раздача подарков
# На праздник в детском саду закупили два вида подарков: конфеты и игрушки. Каждому ребёнку должен был достаться один кулёк конфет и одна игрушка, но в суматохе оказалось, что кто-то недополучил свои подарки. Известно, что каждый ребёнок получил хотя бы что-то одно, а некоторые получили и то, и другое. Составьте программу, которая будет определять, какого подарка ребёнку не хватило. Если ребёнок получил оба подарка, программа должна написать "всё есть".
#
# #### ФОРМАТ ВВОДА
# На первой строке — список детей, получивших кулек конфет (по именам, через запятую и пробел, имена не повторяются);
# на второй строке — список детей, получивших игрушку (по именам, через запятую и пробел, имена не повторяются);
# на третьей строке — имена детей, подарки которых нужно проверить (по именам, через запятую и пробел, имена не повторяются). Гарантируется, что в списке дети, у которых есть как минимум один подарок;
#
# #### ФОРМАТ ВЫВОДА
# Для каждого ребенка вывод на новой строке.
# Имя ребёнка, затем пробел, затем недостающий подарок: "конфеты"/"игрушка"/"всё есть".
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), условный оператор if, цикл for, split(), set(), print()
#
# ЧТО ДЕЛАЕМ:
# Считать строку с именами детей, которые получили конфеты. Затем превратить в список, который превращаем в множество. Сохранить множество в переменную.
# Как в п. 1 считать множество имен детей, получивших игрушку.
# Считать строку с именами детей, которых нужно проверить. Превратить ее в список и сохранить в переменную.
# Записать в новую переменную детей, которые получили оба подарка (пересечение множества из п. 1 и множества из п. 2)
# Реализовать цикл for для списка из п. 3. Для каждого ребенка проверить, принадлежит ли он множеству детей из п. 4:
# если имя находится в множестве, то напечатать, что все есть,
# в ином случае проверить: если имя во множестве из п. 1, то напечатать, что ему нужна игрушка, в ином случае напечатать, что ему нужна конфета.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | Никита, Настя, Максим, Даша, Егор, Ваня, Галя | Даша игрушка |
# | Максим, Никита, Камилла, Коля, Ваня | Коля конфеты |
# | Даша, Коля, Ваня | Ваня всё есть |

# %%
toys = set(input().split(', '))
candies = set(input().split(', '))
children = input().split(', ')

for child in children:
    if child in toys - candies:
        print(child, "игрушка")
    elif child in candies - toys:
        print(child, "конфеты")
    elif child in toys & toys:
        print(child, "всё есть")
# Out:
# Никита, Настя, Максим, Даша, Егор, Ваня, Галя
# Максим, Никита, Камилла, Коля, Ваня
# Даша, Коля, Ваня
# Даша игрушка
# Коля конфеты
# Ваня всё есть

# %% [markdown]
# #### Вопрос 10
# ## Тесты
# Петя решает тесты из контрольно-измерительных материалов и записывает ответы в виде четырехзначного номера вопроса и ответа на него в виде одной заглавной буквы (например, 4578А). Ответы разделяются запятой и пробелом. В конце задачника есть ответы на вопросы, приведенные в виде последовательности заглавных букв. Помогите Пете сравнить, верно ли он решил тест.
#
# #### ФОРМАТ ВВОДА
# Список ответов через запятую и пробел.
# Строка — последовательность заглавных букв латинского алфавита с верными ответами.
#
# #### ФОРМАТ ВЫВОДА
# Две строки:
#
# "Ваш ответ: " и последовательность заглавных букв латинского алфавита.
# Если тест решен верно, выводится "Молодец! Все верно", а если неверно — "Тест решен неверно, правильный ответ: " и последовательность заглавных букв латинского алфавита правильного ответа.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), append(), join(), print(), цикл for, проверка условий с if и else
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную строку — ответы, сразу преобразовав в список через split(). Обратите внимание, что разделитель — запятая и пробел.
# Считать в новую переменную последовательность строку с верными ответами.
# Создать переменную — пустую строку (""), куда мы будем добавлять буквы Петиных ответов.
# Реализовать цикл for для списка из п. 1: для каждого ответа достать последний элемент (это будет как раз буква) и прибавить ее к строке из п. 3.
# Вывести нужную фразу и строку из п. 3.
# Проверить условие: если строка из п.3 совпадает со строкой с верными ответами (из п. 2), то напечатать текст о том, что все верно. В ином случае вывести информацию о том, что тест решен неверно и вывести правильные ответы.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | 4656A, 8777B, 9000C, 8777B | Ваш ответ: ABCB |
# | ABCB | Молодец! Все верно |
# | 1456A, 7896A, 0000E, 7777A | Ваш ответ: AAEA |
# | DCAB | Тест решен неверно, правильный ответ: DCAB |

# %%
# from functools import reduce

qst = input().split(', ')
sol = input()
my_sol = ''.join(list(map(lambda c: c[-1], qst)))
# my_sol =  reduce(lambda x, y: x + y[-1], qst, '')
if sol == my_sol:
    print(f"Ваш ответ: {my_sol}\nМолодец! Все верно")
else:
    print(f"Ваш ответ: {my_sol}\nТест решен неверно, правильный ответ: {sol}")
# Out:
# 4656A, 8777B, 9000C, 8777B
# ABCB
# Ваш ответ: ABCB
# Молодец! Все верно

# %% [markdown]
# #### Вопрос 12
# ## Спортивный сезон
# В течение спортивного сезона проводится 5 соревнований, по результатам которых начисляются очки:
#
# Если спортсмен выиграл, то начисляется 5 очков рейтинга.
# Если не выиграл, но вошел в первую тройку — 3 очка.
# За участие без призового места начисляется 1 очко.
# Напишите программу, которая по турнирной таблице и фамилии спортсмена считает рейтинг (сумму очков) этого спортсмена.
#
# #### ФОРМАТ ВВОДА
# Турнирная таблица — пять строк, в каждой из которых через запятую имена спортсменов в том порядке, какие места они заняли на соответствующем соревновании.
# После этого вводится еще одна строка — имя спортсмена
#
# #### ФОРМАТ ВЫВОДА
# Целое число — рейтинг введенного спортсмена
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# range(), input(), split(), append(), index(), print(), цикл for, проверка условий
#
# ЧТО ДЕЛАЕМ:
# Создать пустой список, куда мы запишем турнирную таблицу.
# Создать переменную-счетчик, равную 0, в которой мы будем считать баллы для выбранного спортсмена.
# Реализовать цикл for 5 раз (воспользуйтесь range(5)): считать строку с фамилиями и прикрепить ее к списку из п. 1.
# Считать строку, в которую запишем фамилию спортсмена, для которого будем считать баллы.
# Пройтись циклом по списку строк из п. 1. Для каждой строки турнирной таблицы делаем следующую манипуляцию:
# C помощью split() превращаем строку в список фамилий и сохраняем список в переменную.
# Проверяем условие, есть ли спортсмен из п. 1 в этом списке. Если есть, то дальше проверяем вложенные условия:
# если индекс спортсмена равен нулю, то прибавляем 5 к переменной из п. 2,
# если нет, то проверяем не равен ли индекс 1 или 2 — в этом случае прибавляем 3,
# во всех остальных случаях прибавляем 1 (ведь мы уже проверили, что спортсмен есть в списке).
# По окончании работ цикла, напечатайте переменную из п. 2 — рейтинг спортсмена.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | Иванов, Петров, Сидоров, Пупкин, Яблочкин | 12 |
# | Петров, Яблочкин, Макаров, Смирнов, Кузнецов |
# | Петров, Пупкин, Смирнов, Сидоров |
# | Иванов, Кузнецов, Пупкин, Макаров |
# | Пупкин, Петров, Яблочкин, Сидоров, Смирнов |
# | Пупкин |

# %%
def get_rate(place):
    if place == 0:
        return 5
    elif place in (1, 2):
        return 3
    else:
        return 1

N = 5
dct = dict()

for n in range(N):
    names = input().split(', ')
    for i, v in enumerate(names):
        dct[v] = dct.get(v, 0) + get_rate(i)

print(dct.get(input(), 0))
# Out:
# Иванов, Петров, Сидоров, Пупкин, Яблочкин
# Петров, Яблочкин, Макаров, Смирнов, Кузнецов
# Петров, Пупкин, Смирнов, Сидоров
# Иванов, Кузнецов, Пупкин, Макаров
# Пупкин, Петров, Яблочкин, Сидоров, Смирнов
# Пупкин
# 12

# %% [markdown]
# #### Вопрос 13
# ## Корпоративные почты
# Компания "Пампарам" регистрирует сотрудникам корпоративные почты и хочет оставить им логины, которыми они уже привыкли пользоваться. Единственное условие — почты не должна начинаться с цифр или c точки, тире, нижнего подчеркивания, поэтому если такие символы встречаются, то они должны быть отброшены. Помогите компании сформировать новый список почт на домене pamparam.ru
#
# #### ФОРМАТ ВВОДА
# Список почтовых адресов сотрудников компании через точку с запятой и пробел.
# Гарантируется, что в каждом адресе есть хотя бы одна буква.
#
# #### ФОРМАТ ВЫВОДА
# Список новых почтовых адресов сотрудников компании — домены (то, что идет после @), должны быть заменены на домен pamparam.ru, а с левой стороны должны быть отброшены символы, на которые не должен начинаться почтовый адрес.
# Список выведите через точку с запятой и пробел.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), append(), lstrip(), join(), цикл for, print()
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную почтовые адреса, сразу превратить их как список.
# Создать переменную — пустой список, куда мы будем записывать новые адреса.
# Реализовать цикл for для списка из п. 1:
# для каждого адреса электронной почты убрать цифры, точки, тире, если они есть в начале (с помощью lstrip('_-.0123456789')),
# разделить на логин и домен с помощью разбивки (split)по символу собаки ('@'), взять только сам логин и прибавить к нему '@pamparam.ru',
# получившийся новый адрес добавить в список из п. 2.
# Напечатать список, преобразованный в корректную строку с помощью join или использования * внутри print().
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | 0-1in.ianv00@gmail.com; 42.petr.petrov@mail.ru; _1990_olg0a@hse.ru | in.ianv00@pamparam.ru; petr.petrov@pamparam.ru; olg0a@pamparam.ru  |

# %%
eml = input().split('; ')
for i in range(len(eml)):
    eml[i] = eml[i].lstrip('0123456789.-_')
    eml[i] = eml[i][:eml[i].index('@') + 1] + 'pamparam.ru'
print('; '.join(eml))
# Out:
# 0-1in.ianv00@gmail.com; 42.petr.petrov@mail.ru; _1990_olg0a@hse.ru
# in.ianv00@pamparam.ru; petr.petrov@pamparam.ru; olg0a@pamparam.ru

# %% [markdown]
# #### Вопрос 14
# ## Регистрация на сайте
# Для регистрации на сайте нужно придумать пароль, который удовлетворяет следующим требованиям:
#
# В нем обязательно встречаются и буквы и цифры
# При этом не встречается никаких других символов
# В нем есть хотя бы одна заглавная буква и хотя бы одна строчная
# Напишите программу, которая проверяет пароль на соответствие требованиям.
#
# #### ФОРМАТ ВВОДА
# Строка, содержащая пароль.
#
# #### ФОРМАТ ВЫВОДА
# Строка "Пароль валидный", если пароль соответствует требования, строка "Пароль невалидный" в ином случае.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), isupper(), islower(), isalnum(), isdigit(), isalpha(), проверка условий
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную строку с паролем.
# Проверить условие:
# если верно, что строка содержат только буквы цифры, И
# неверно, что он содержит только цифры, И
# неверно, что она содержит только буквы, И
# неверно, что только буквы в нижнем регистре, И
# неверно, что только в верхнем,
# то напечатать текст о том, что пароль валидный. В ином случае, напечатать текст о том, что пароль невалидный.
# Не пугайтесь этого длинного условия! На самом деле пункты 1-4 проверяют взаимоисключающие события. Если в пароле не только цифры и не только буквы, значит он представляет с собой смесь цифр и букв.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | Qwerty12345 | Пароль валидный |

# %%
psw = input()
if psw != psw.lower() and psw != psw.upper() and psw.isalnum() and not (psw.isalpha() or psw.isdigit()):
    print("Пароль валидный")
else:
    print("Пароль невалидный")
# Out:
# Qwerty12345
# Пароль валидный

# %% [markdown]
# #### Вопрос 15
# ## Зашифрованные сообщения
# Маша и Вася общаются между собой зашифрованными сообщениями: первые два и последние два символа в каждом слове не влияют на смысл, нужно читать только с третьего до третьего с конца включительно символы. Пробелы при этом стоят на своих местах. Напишите программу, которая будет расшифровывать такие сообщения.
#
# #### ФОРМАТ ВВОДА
# Зашифрованное сообщение в одну строку (гарантируется, что в каждом слове хотя бы 5 букв).
#
# #### ФОРМАТ ВЫВОДА
# Расшифрованное сообщение в одну строку.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), split(), append(), print(), join(), цикл for
#
# ЧТО ДЕЛАЕМ:
# Считать в новую переменную зашифрованное сообщение, сразу преобразовать в список.
# Создать переменную — пустой список.
# Реализовать цикл для списка из п.1:
# для каждого слова из списка убрать первые два и последние два символа (срез [2:-2]),
# записать результат как элемент в список из п.2.
# Вывести расшифрованное сообщение c помощью join() или распаковки списка.
# ```
# </details>
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | ОВнеХё Щбмогуел жврешитьро зрзадачууш | не могу решить задачу |

# %%
s_in = input().split()
s_out = list(map(lambda w: w[2:-2], s_in))
print(' '.join(s_out))
# Out:
# ОВнеХё Щбмогуел жврешитьро зрзадачууш
# не могу решить задачу
