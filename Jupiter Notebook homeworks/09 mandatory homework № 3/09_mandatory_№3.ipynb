# %% [markdown]
# #### Вопрос 1
# ## Стихи
# Дан файл poetry.txt, который содержит в себе стихотворение. Выведите его построчно на экран.
#
# #### ФОРМАТ ВВОДА
# Файл poetry.txt в кодировке utf-8.
#
# #### ФОРМАТ ВЫВОДА
# Текст файла построчно.
# Не забудьте удалить знак перехода на новую строку из строки файла перед тем, как печатать ее!
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используется файл poetry.txt. Вы можете скачать его и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :-|
# | 0 | Macavity's a Mystery Cat: he's called the Hidden Paw - |
# | | For he's the master criminal who can defy the Law. |
# | | He's the bafflement of Scotland Yard, the Flying Squad's despair: |
# | | For when they reach the scene of crime – Macavity's not there! |

# %%
try:
    with open('poetry.txt', 'r', encoding='utf-8') as file:
        poetry = file.read()
except FileNotFoundError:
    print("File Not Found")
    
for line in poetry:
    print(line, end="")
# Out:
# Macavity's a Mystery Cat: he's called the Hidden Paw -
# For he's the master criminal who can defy the Law.
# He's the bafflement of Scotland Yard, the Flying Squad's despair:
# For when they reach the scene of crime – Macavity's not there!

# %% [markdown]
# #### Вопрос 2
# ## Письма Деда Мороза
# Дед Мороз получил письма от детей, и пишет им ответы. На ввод подаются имена детей, а в файл нужно записать текст благодарности для каждого из них.
#
# #### ФОРМАТ ВВОДА
# Целое число N - количество имен детей, которым нужно ответить.
# N имен детей — каждое с новой строки.
#
# #### ФОРМАТ ВЫВОДА
# Файл mails.txt в кодировке utf-8, где на каждой строке записана благодарность ребенку в формате: "Спасибо, <ИМЯ>! Твой подарок ждет тебя под елкой!"
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте получается файл mails.txt. Вы можете скачать его и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# **Для примера:**
#
# | Ввод | Результат |
# | :- | :-|
# | 3 | FILE: Спасибо, Маша! Твой подарок ждет тебя под елкой! |
# | Маша | Спасибо, Паша! Твой подарок ждет тебя под елкой! |
# | Паша | Спасибо, Глаша! Твой подарок ждет тебя под елкой! |
# | Глаша | |

# %%
names = [input() for _ in range(int(input()))]

with open('mails.txt', 'w', encoding='utf-8') as file_out:
    [print(f"Спасибо, {name}! Твой подарок ждет тебя под елкой!", file=file_out) for name in names]
# Out:
# 3
# Маша
# Паша
# Глаша

# %% [markdown]
# #### Вопрос 3
# ## Оценки
# У Ивана Петровича, профессора лингвистики, есть файл grades.txt с именами и оценками студентов. В каждой строке содержится информация об одном студенте, имя и оценки между собой разделены пробелами. Помогите Ивану Петровичу сохранить в новый файл информацию только о второй оценке студента.
#
# #### ФОРМАТ ВВОДА
# Файл grades.txt в кодировке utf-8 с именами и оценками студентов, разделенными пробелом.
#
# #### ФОРМАТ ВЫВОДА
# Файл second_grade.txt в кодировке utf-8, где на каждой строке записано только имя студента и его вторая оценка из списка, разделенные пробелами. Строки идут в том же порядке, что и в оригинальном файле.
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используются файлы grades.txt и second_grade.txt Вы можете скачать их и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :-|
# | 0 | FILE: Кирилл 4 |
# | | Дмитрий 5 |
# | | Константин 5 |
# | | Мария 4 |
# | | Дарья 5 |
# | | Демьян 3 |
# | | Павел 4 |

# %%
with open('grades.txt', 'r', encoding='utf-8') as file_in, open('second_grade.txt', 'w', encoding='utf-8') as file_out:
    for row in file_in:
        s = row.split()
        print(f"{s[0]} {s[2]}", file=file_out)

# %% [markdown]
# #### Вопрос 4
# ## Цветочный магазин
# У Леши свой цветочный магазин, для которого он ведет статистику.
#
# Каждый заказ он записывает с новой строки в файл по типу "Роза 1500", где "Роза" — это цветок, который купили, а 1500 — сумма покупки. Помогите Леше преобразовать статистику из его файла в словарь Python.
#
# #### ФОРМАТ ВВОДА
# Файл orders.txt, где на каждой строке записан заказ в формате "<название цветка> <сумма>", разделенные пробелом.
#
# #### ФОРМАТ ВЫВОДА
# Словарь Python, где ключи — названия цветов, а значения — общая выручка. Ключи добавляются в словарь в том порядке, в котором они впервые встречаются в файле.
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используется файл orders.txt. Вы можете скачать его и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :-|
# | 0 | {'Роза': 4350, 'Гербера': 630, 'Лилия': 1200} |

# %%
try:
    with open('orders.txt', 'r', encoding='utf-8') as file:
        orders = file.readlines()
except FileNotFoundError:
    print("File Not Found")

dct = {}
for row in orders:
    flower = row.split()
    dct[flower[0]] = dct.get(flower[0], 0) + int(flower[1])

print(dct)
# Out:
# {'Роза': 4350, 'Гербера': 630, 'Лилия': 1200}

# %% [markdown]
# #### Вопрос 5
# Петя хочет узнать перевод интересующего слова. У Пети есть файл — англо-русский словарь dictionary.txt, в котором записаны пары слов на английском и русском языке. Между собой слова разделены тире с пробелами (' – '), а каждая пара слов печатается на новой строке. Помогите Пете написать программу, которая будет находить перевод введенного английского слова на русский язык.
#
# #### ФОРМАТ ВВОДА
# Файл dictionary.txt в кодировке utf-8.
# Слово на английском языке — вводится с клавиатуры.
# Гарантируется, что введенное слово есть в файле.
#
# #### ФОРМАТ ВЫВОДА
# Строка, перевод введенного слова.
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используется файл dictionary.txt. Вы можете скачать его и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# **Для примера:**
#
# | Тест | Ввод | Результат |
# | - | - | :-|
# | 0 | dog | собака |

# %%
try:
    with open('dictionary.txt', 'r', encoding='utf-8') as file_in:
        dictionary = file_in.readlines()
except FileNotFoundError:
    print("File Not Found")

dct = {row.split(' – ')[0]: row.split(' – ')[1][:-1] for row in dictionary}
print(dct[input()])
# Out:
# dog
# собака

# %% [markdown]
# #### Вопрос 6
# ## Генератор приглашений
# Университет периодически организует конференции для студентов. Для каждой конференции организаторы формируют и рассылают всем зарегистрировавшимся участникам приглашения с указанием имени зарегистрировавшегося, названия конференции, времени начала и регистрационного номера участника.
#
# Напишите программу, которая будет автоматически генерировать и сохранять в файл такие приглашения.
#
# #### ФОРМАТ ВВОДА
# Строка с названием конференции
# Далее с новой строки вводится время начала конференции
# Далее с новой строки вводится список имен зарегистрировавшихся участников конференции через запятую и пробел
#
# #### ФОРМАТ ВЫВОДА
#
# Файл invitations.txt в кодировке utf-8
# Внутри файла для каждого зарегистрировавшегося участника должно быть записано приглашение в формате:
# "Добрый день, <имя>!
#
# Вы зарегистрировались на конференцию "<название конференции>", которая состоится <время начала конференции>.
#
# Ваш регистрационный номер - <номер>."
#
# Регистрационные номера генерируются как порядковый номер участника во введенном списке, начиная с 1. Записывать приглашения в файл нужно в том же порядке.
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте получается файл invitations.txt. Вы можете скачать его и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), .split(), with open() as, for, range(), len(), f-строки, print() или .write()
# ЧТО ДЕЛАЕМ:
# Считываем в новую переменную строку с названием конференции.
# Считываем в новую переменную строку с временем начала конференции.
# Считываем в новую переменную строку с участниками конференции и преобразовываем ее в список участников.
# С помощью конструкции with open() as открываем файл invitation.txt в режиме записи ('w'). Не забудьте выставить кодировку! Внутри конструкции запускаем цикл for для всех индексов элементов списка из п. 3:
# Создаем приглашение в формате, указанном в условии для участника с текущим индексом, и печатаем его в файл invintations.txt. Напечатать информацию в файл можно двумя способами:
# print(), где первым аргументом будет строка, а вторым параметр file=, которому присваивается название переменной-коннектора из конструкции with open().
# Метод .write(), вызываемой от переменной-коннектора с одним аргументом — строкой, которую нужно записать. В этом случае не забудьте добавить '\n' в конце строки.
# ```
# </details>
#
# **Для примера:**
#
# | Тест | Ввод | Результат |
# | - | -: | :-|
# | 0 | Фантастические твари и где они обитают | FILE: Добрый день, Иван Иванов!
# | | 12 ноября в 18:00 | Вы зарегистрировались на конференцию "Фантастические твари и где они обитают", которая состоится 12 ноября в 18:00.
# | | Иван Иванов, Петр Петров, Анна Смирнова, Татьяна Кузнецова, Макар Макаров | Ваш регистрационный номер - 1.
# | | | Добрый день, Петр Петров!
# | | | Вы зарегистрировались на конференцию "Фантастические твари и где они обитают", которая состоится 12 ноября в 18:00.
# | | | Ваш регистрационный номер - 2.
# | | | Добрый день, Анна Смирнова!
# | | | Вы зарегистрировались на конференцию "Фантастические твари и где они обитают", которая состоится 12 ноября в 18:00.
# | | | Ваш регистрационный номер - 3.
# | | | Добрый день, Татьяна Кузнецова!
# | | | Вы зарегистрировались на конференцию "Фантастические твари и где они обитают", которая состоится 12 ноября в 18:00.
# | | | Ваш регистрационный номер - 4.
# | | | Добрый день, Макар Макаров!
# | | | Вы зарегистрировались на конференцию "Фантастические твари и где они обитают", которая состоится 12 ноября в 18:00.
# | | | Ваш регистрационный номер - 5.

# %%
theme = input()
dt = input()
names = input().split(', ')

with open('invitations.txt', 'w', encoding='utf-8') as file_out:
    for i, name in enumerate(names, 1):
        print(f"Добрый день, {name}!", file=file_out)
        print(f"Вы зарегистрировались на конференцию \"{theme}\", которая состоится {dt}.", file=file_out)
        print(f"Ваш регистрационный номер - {i}.", file=file_out)
# Out:
# Фантастические твари и где они обитают
# 12 ноября в 18:00
# Иван Иванов, Петр Петров, Анна Смирнова, Татьяна Кузнецова, Макар Макаров

# %% [markdown]
# #### Вопрос 7
# ## Анализ тегов Твиттера
# В текстовом файле находится выгрузка постов из Твиттера, за некоторый период, в которых встречаются теги. Выясните, какие теги являлись более популярными, а какие менее, подсчитав количество употреблений каждого.
#
# ## ФОРМАТ ВВОДА
# Текстовый файл tweets.txt, в котором записана подборка постов из Твиттера, размеченных тегами. Тегом считается любое слово, начинающееся с символа '#'. Гарантируется, что все теги записаны маленькими буквами, и в них не встречаются знаки препинания.
#
# #### ФОРМАТ ВЫВОДА
# Текстовый файл tags.txt в кодировке utf-8, где каждый твит, использованный в файле tweets.txt, записан в формате "тег: <тег>, упоминаний: <кол-во упоминаний>". Каждый тег должен быть записан на отдельной строке, теги нужно отсортировать по количеству упоминаний от самого большого к самому маленькому
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используются файлы tags.txt и tweets.txt. Вы можете скачать их и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# def, return, with open(), for, if/else, sorted(), print() или .write()
# ЧТО ДЕЛАЕМ:
# Создаем пустой словарь для тегов и количества их упоминаний (теги будут ключами, количество их упоминаний — значениями).
# Определяем функцию которая принимает один параметр — ключ словаря, а возвращает значение этого ключа из словаря из п.1. Мы будем позже использовать ее для сортировки по ключу.
# Открываем файл tweets.txt. Реализуем цикл for для строк файла — для каждой строки запускаем еще один цикл for по строке, разбитой на слова по пробелам:
# Проверяем каждое слово: если это тег (т.е. если первый символ слова #) и его еще нет среди ключей из п.1, то этот тег записывается в словарь и ему присваивается значение 1.
# Если это тег и он уже есть в словаре из п.1, то обновляем значение этого ключа — прибавляем к нему 1 (увеличиваем на 1 количество упоминаний).
# По завершении работа цикла открываем файл tags.txt в режиме записи с нужной кодировкой. Внутри конструкции with open() запускаем цикл for по отсортированному словарю из п.1. Не забудьте добавить ключ сортировки (key=) равный названию функции из п.2, а также добавить параметр для сортировки по убыванию. Каждый ключ словаря и его значение печатаем в файле tags.txt на новой строке в заданном формате.
# ```
# </details>
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :-|
# | 0 | FILE: тег: #lorem, упоминаний: 7 |
# | | тег: #dolor, упоминаний: 6 |
# | | тег: #hendrerit, упоминаний: 5 |
# | | тег: #risus, упоминаний: 4 |
# | | тег: #ipsum, упоминаний: 3 |
# | | тег: #diam, упоминаний: 2 |
# | | тег: #felis, упоминаний: 1 |

# %%
try:
    with open('tweets.txt', 'r', encoding='utf-8') as file:
        tweets = file.read().split()
except FileNotFoundError:
    print("File Not Found")

tags = list(filter(lambda t: t[0] == '#', tweets))
dct = {}
for tag in tags:
    dct[tag] = dct.get(tag, 0) + 1
dct = dict(sorted(dct.items(), key=lambda item: item[1], reverse=True))

with open('tags.txt', 'w', encoding='utf-8') as file_out:
    for t, v in dct.items():
        print(f"тег: {t}, упоминаний: {v}", file=file_out)

# %% [markdown]
# #### Вопрос 8
# ## Рассылка оценок
# Преподаватель Елена Семеновна в конце семестра подсчитывает итоговую оценку и делает рассылку, где сообщает каждому студенту оценку, а несдавшим сообщает дату пересдачи. Оценка считается по такому правилу: накопленная оценка считается с коэффициентом 0.4, оценка за экзамен считается с коэффициентом 0.6, результат округляется.
#
# Напишите программу, которая посчитает итоговые оценки и сгенерирует тексты рассылок для Елены Семеновны.
#
# #### ФОРМАТ ВВОДА
# Структурированный файл students.csv в кодировке utf-8, где на каждой строке содержится информация о студенте, разделенная точкой с запятой:  имя студента, адрес его электронной почты, накопленная оценка и оценка за экзамен по 10-балльной шкале.
#
# #### ФОРМАТ ВЫВОДА
# Текстовый файл emails.txt в кодировке utf-8, где для каждого студента записан текст для рассылки в следующем формате:
# "To: <адрес электронной почты>
# Добрый день, <имя студента>!
# Ваша итоговая оценка за курс - <оценка>."
#
# Далее для сдавших экзамен (получивших оценку 4 и выше) пишется строка "Хороших каникул!", а для несдавших - "Пересдача состоится 15 января в 10:00, место будет сообщено позднее."
#
# Рассылки должны быть записаны в файл в том же порядке, в каком имена студентов встречаются во входном файле.
# Для округления итоговой оценки используйте функцию round()
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используются файлы students.csv и emails.txt. Вы можете скачать их и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# with open() as, for, .strip(), .split(), round(), int(), if/else, print() или .write()
# ЧТО ДЕЛАЕМ:
# Открываем файл students.csv в режиме для чтения. Внутри конструкции with open() as открываем файл emails.txt в режиме записи и в правильной кодировке. Внутри второй конструкции with open() as запускаем цикл по строкам файла students.csv. На каждой итерации цикла необходимо:
# Преобразовать строку с информацией о студенте в список с его характеристиками.
# Вычислить итоговую оценку студента по формуле (не забудьте преобразовать оценки из списка в числа!)
# Напечатать в файл emails.txt первые три строки текста для рассылки в формате, указанном в условии. Используйте f-строки, чтобы подставить значения переменных в шаблон.
# Проверить условие: если итоговая оценка меньше 4, то допечатать текст в рассылку о пересдаче в файле emails.txt. В ином случае допечатать пожелание хороших каникул.
# ```
# </details>
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :-|
# | 0 | FILE: To: ivanov@hse.ru |
# | | Добрый день, Иван Иванов! |
# | | Ваша итоговая оценка за курс - 6. |
# | | Хороших каникул! |
# | | ... |

# %%
try:
    with open('students.csv', 'r', encoding='utf-8') as file_in, open('emails.txt', 'w', encoding='utf-8') as file_out:
        for row in file_in:
            st = row.strip().split(';')
            grade = int(round(int(st[2]) * 0.4 + int(st[3]) * 0.6))
            print(f"To: {st[1]}", f"Добрый день, {st[0]}!", f"Ваша итоговая оценка за курс - {grade}.", sep="\n", file=file_out)
            if grade >= 4:
                print(f"Хороших каникул!", file=file_out)
            else:
                print(f"Пересдача состоится 15 января в 10:00, место будет сообщено позднее.", file=file_out)

except FileNotFoundError:
    print("File Not Found")

# %% [markdown]
# #### Вопрос 9
# ## Сашина кофейня — 2
# Саша открыла кофейню. Там продают капучино, латте и раф маленького, среднего и большого размера. Также в кофе могут добавить сироп. Для маленького используется 10 мл сиропа, для среднего — 20 мл, для большого — 30 мл.
#
# Каждый день бариста ведет отчет о том, какие напитки он продал. Помогите Саше подсчитать анализ расхода сиропа для какого-либо вида кофе.
#
# #### ФОРМАТ ВВОДА
# Структурированный файл coffee-statistics-2.csv в кодировке utf-8, где на каждой строке записана информация о проданном кофе, разделенная  точкой с запятой: его вид, размер ('маленький', 'средний', 'большой') и вкус добавленного сиропа (если есть).
# Строка с названием вида кофе, для которого нужно провести подсчеты, вводится с клавиатуры.
# Гарантируется, что в файле есть хотя бы одна запись с введенным видом кофе, в который добавили сироп.
#
# #### ФОРМАТ ВЫВОДА
# Структурированный файл syrups-statistics.csv в кодировке utf-8, где на каждой строке записана информация о расходе каждого сиропа, разделенная точкой с запятой: вкус сиропа, далее расход для введенного вида кофе.
# Например, "кленовый;90".
# Строчки располагаются в алфавитном порядке по названию сиропов.
#
# #### ДОПОЛНИТЕЛЬНО
#
# В открытом тесте используются файлы coffee-statistics-2.csv и syrups-statistics.csv. Вы можете скачать их и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# input(), with open() as, for, .strip(), .split(), if, print() или .write()
# ЧТО ДЕЛАЕМ:
# Cоздаем пустой словарь, в котором в качестве ключей будут сиропы, а в качестве значений — их расход в миллилитрах.
# Считываем в новую переменную название вида кофе, для которого нужно провести подсчеты.
# Открываем файл coffee-statistics-2.csv в режиме для чтения. Внутри конструкции with open() as реализуем цикл for для строк этого файла:
# Преобразуем строку в список.
# Проверяем условие: если вид кофе (первый элемент списка) совпадает со значением переменной из п.2, а строка с названием сиропа не является пустой (последний элемент списка не равен ""), то раcсчитываем объем сиропа в зависимости от размера кофе — 10 мл для маленького, 20 мл для среднего, 30 мл для большого. Получаем некоторую переменную, в которой хранится расход сиропа для данного напитка.
# Далее проверяем, есть ли ключ с названием этого сиропа в словаре из п.1 (только в том случае, если мы все еще работаем со строкой об интересующем нас кофе, в который добавили сироп!). Если такого ключа нет — создаем ключ и присваиваем ему значение с количеством потраченного сиропа. Если такой ключ есть, то увеличиваем его значение на количество потраченного сиропа.
# По завершении работы цикла открываем файл syrups-statistics.csv в режиме для чтения и в правильной кодировке.
# Внутри второй конструкции with open() as реализуем цикл for для отсортированного по алфавиту словаря из п.1: печатаем в файл название сиропа и его расход в указанном в условии формате.
# ```
# </details>
#
# **Для примера:**
#
# | Тест | Ввод | Результат |
# | - | - | :- |
# | 0 | латте | FILE: ванильный;90 |
# | | | карамельный;190 |
# | | | кленовый;170 |
# | | | кокосовый;250 |
# | | | розовый;150 |
# | | | шоколадный;190 |

# %%
coffee = input()

with open('coffee-statistics-2.csv', 'r', encoding='utf-8') as file_in, open('syrups-statistics.csv', 'w', encoding='utf-8') as file_out:
    syrups_stat = {}
    syrups_size = {"маленький": 10, "средний": 20, "большой": 30}
    for row in file_in:
        c = row.strip().split(';')
        if coffee == c[0] and c[-1]:
            syrups_stat[c[-1]] = syrups_stat.get(c[-1], 0) + syrups_size[c[-2]]
    syrups_stat = dict(sorted(syrups_stat.items()))

    for s, v in syrups_stat.items():
        print(f"{s};{v}", file=file_out)
# Out:
# латте

# %% [markdown]
# #### Вопрос 10
# ## Сашина кофейня — 3
# Саша открыла кофейню. Там продаются различные напитки в трех размерах — маленькие, средние и большие. Цены на эти напитки записаны в прайс-листе.
#
# Каждый день бариста записывает, какие напитки он продал. Помогите Саше по записям баристы составить отчет о выручке за день.
#
# #### ФОРМАТ ВВОДА
# Структурированный файл price-list.csv в кодировке utf-8, где на каждой строке записаны цены на какой-либо вид кофе: вида кофе, далее в каждой три целых числа — цены на маленький, средний и большой напиток. Данные разделены точкой с запятой.
# Структурированный файл coffee-statistics-3.csv в кодировке utf-8, где на каждой строке записана информация о проданном кофе: его вид и размер ('маленький', 'средний', 'большой'). Данные разделены точкой с запятой.
#
# #### ФОРМАТ ВЫВОДА
# Структурированный файл sale-statistics.csv в кодировке utf-8, где на каждой строке записана информация о выручке за каждый вид кофе: его название и заработанная сумма. Данные разделены точкой с запятой.
# Результат отсортируйте по названию напитков в алфавитном порядке.
# Разделителем во всех таблицах служит точка с запятой.
#
# #### ДОПОЛНИТЕЛЬНО
# В открытом тесте используются файлы coffee-statistics-3.csv, price-list.csv и sale-statistics.csv. Вы можете скачать их и проверить свое решение локально.
# В примере в первой колонке отображается номер теста (0 — открытый тест), считывать это число или использовать его в вашем решении не нужно.
#
# <details>
#
#   <summary>>>> КЛИКНИТЕ, ЧТОБЫ ПОКАЗАТЬ/СКРЫТЬ ПОДСКАЗКУ</summary>
#
# ```
# Если у вас не получилось решить задачу самостоятельно, можете воспользоваться нашим алгоритмом с подсказкой.
#
# Помните, предложенный алгоритм и элементы не всегда единственный способ решить задачу — необязательно использовать этот вариант, если вы придумали другой.
#
# ЧТО ИСПОЛЬЗУЕМ:
# with open() as, for, .strip(), .split(), list(), map(), int()
# ЧТО ДЕЛАЕМ:
# Создаем пустой словарь для цен.
# Открываем файл price-list.csv и реализуем цикл for для каждой строки из этого файла.
# преобразовываем строку с информацией о кофе в список.
# записываем в словарь из п.2 информацию о кофе: в качестве ключа должно быть название вида кофе, а в качестве значения список цен для напитков этого вида кофе разного размера (не забудьте преобразовать эти цены в целые числа с помощью map()).
# По окончании работы цикла у нас будет словарик, в котором мы сможем посмотреть, сколько стоит тот или иной напиток.
# Создаем пустой словарь для подсчета выручки.
# Открываем файл coffee-statistics-3.csv и реализуем цикл for для каждой строки.
# Преобразуем строку с информацией о проданном кофе в список и сохраним в переменную название кофе (его первый элемент) и размер (его второй элемент).
# Делаем проверку — если название кофе нет в словаре из п. 3, то создаем такой ключ и присваиваем ему 0.
# Делаем новую проверку — если размер кофе — маленький, то к ключу с названием этого кофе в словаре из п.3 добавляем первый элемент из списка, соответствующего названию этого кофе из словаря из п. 1.
# Делаем такие же проверки для среднего и большого размера.
# По окончании работы цикла у нас будет словарик, в котором собрана информация по общей выручке для всех видов кофе.
# Открываем файл sale-statistics.csv в режиме записи и в нужной кодировке. Реализуем цикл for для отсортированных ключей словаря из из п.3: на каждой итерации напечатать в файл ключ словаря (название кофе) и значение для ключа (выручка) в формате, заданном в условии
# ```
# </details>
#
# **Для примера:**
#
# | Тест | Результат |
# | :- | :- |
# | 0 | FILE: глясе;4860 |
# | | капучино;3380 |
# | | латте;3116 |
# | | мокачино;2880 |
# | | раф;4270 |
# | | эспрессо;3810 |

# %%
with open('price-list.csv', 'r', encoding='utf-8') as file_price, \
        open('coffee-statistics-3.csv', 'r', encoding='utf-8') as file_coffee, \
        open('sale-statistics.csv', 'w', encoding='utf-8') as file_out:
    coffee_size = {"маленький": 0, "средний": 1, "большой": 2}

    price = {}
    for row in file_price:
        coffee = row.strip().split(';')
        price[coffee[0]] = list(map(int, coffee[1:]))

    sales = {}
    for row in file_coffee:
        coffee = row.strip().split(';')
        sales[coffee[0]] = sales.get(coffee[0], 0) + price[coffee[0]][coffee_size[coffee[1]]]
    sales = dict(sorted(sales.items()))

    for c, v in sales.items():
        print(f"{c};{v}", file=file_out)
